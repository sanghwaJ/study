# %%
# Softeer - 장애물 인식 프로그램

import sys
#input = sys.stdin.readline

N = int(input())

for i in range(N):
    block = input()

# %%
nums = [1, 3, 5, 7, 9, 11, 13, 15]
for num in nums:
    print(f'{num:02d}', end=' ')
# Out:
# 01 03 05 07 09 11 13 15
