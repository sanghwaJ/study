# %%
# Softeer - 

import sys
# input = sys.stdin.readline
s = 'H HP HP PH HP PH PP PH PH PH P'

for i in range(len(s)):
    if s[i:i+2] == 'PH':
        print(s[i:i+2])
    elif s[i:i+2] == 'HP':
        print(s[i:i+2])
# Out:
# HP
# PH
# HP
# PH
# HP
# PH
# HP
# PH
# HP
# PH
# HP
# PH
# HP

# %%
lst = ['1', '2', '3']

lst.pop()
print(lst)
# Out:
# ['1', '2']
